# %% [markdown]
# # Import Dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
columns = [
    "Salary cap", "Outcome in wins", "Playoffs", "Wins", "Losses", "PCT", "FG",
    "FGA", "FG%", "3P", "3PA", "3P%","2P", "2PA", "2P%", "FT", "FTA", "FT%", "ORB", "DRB", "TRB", 
    "AST", "STL", "BLK", "TOV", "PF", "PTS"
]

target = ["Playoffs"]

# %%
# Load the data
file_path = Path('../Data/NBA_Salary3.csv')
df = pd.read_csv(file_path)[:-2]
# df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
df.dtypes
# Out:
# Salary cap      int64
# Playoffs       object
# Wins            int64
# Losses          int64
# PCT           float64
# FG            float64
# FG%           float64
# 3P            float64
# 3P%           float64
# 2P            float64
# 2P%           float64
# FT            float64
# FT%           float64
# ORB           float64
# DRB           float64
# TRB           float64
# AST           float64
# STL           float64
# BLK           float64
# TOV           float64
# PF            float64
# PTS           float64
# dtype: object

# %% [markdown]
# # Split the Data into Training and Testing

# %%
#Create our features
# X = pd.get_dummies(df, columns= ["Salary cap",
#                                 "PCT",
#                                 "FG%",
#                                 "3P%",
#                                 "2P%",
#                                 "FT%",
#                                 "TRB",
#                                 "AST",
#                                 "STL",
#                                 "BLK",
#                                 "TOV",
#                                 "PTS"]).drop('Playoffs', axis=1)

X = df.copy()
X = X.drop("Playoffs", axis=1)

# Create our target

y = df['Playoffs']
X.head()
# Out:
#    Salary cap  Wins  Losses    PCT    FG    FG%    3P    3P%    2P    2P%  \
# 0   178980766    53      29  0.646  40.5  0.469  14.3  0.364  26.2  0.557
# 1   174811922    44      38  0.537  42.0  0.475  11.5  0.361  30.5  0.538
# 2   168378382    42      40  0.512  40.1  0.458  12.8  0.374  27.3  0.512
# 3   164409293    33      49  0.402  41.6  0.469  12.0  0.347  29.7  0.546
# 4   162135421    51      31  0.622  41.8  0.468  14.1  0.366  27.8  0.544
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.769   9.8  35.7  45.5  27.1  8.8  4.5  14.9  21.0  111.0
# 1  ...  0.805  10.3  34.1  44.4  25.3  7.1  5.5  14.1  20.4  112.0
# 2  ...  0.793   9.1  34.9  44.0  24.0  7.4  5.0  13.7  18.6  108.4
# 3  ...  0.732   9.5  34.5  44.0  24.0  7.6  5.2  14.5  20.2  112.1
# 4  ...  0.776  10.2  36.5  46.7  23.9  7.6  4.0  13.4  18.2  115.5
#
# [5 rows x 21 columns]

# %%
# Convert the target column values to 1 and 0 based on their values
x = {'Yes': '1'}   
df = df.replace(x)

x = {'No': '0'}   
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    Salary cap Playoffs  Wins  Losses    PCT    FG    FG%    3P    3P%    2P  \
# 0   178980766        1    53      29  0.646  40.5  0.469  14.3  0.364  26.2
# 1   174811922        1    44      38  0.537  42.0  0.475  11.5  0.361  30.5
# 2   168378382        0    42      40  0.512  40.1  0.458  12.8  0.374  27.3
# 3   164409293        0    33      49  0.402  41.6  0.469  12.0  0.347  29.7
# 4   162135421        1    51      31  0.622  41.8  0.468  14.1  0.366  27.8
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.769   9.8  35.7  45.5  27.1  8.8  4.5  14.9  21.0  111.0
# 1  ...  0.805  10.3  34.1  44.4  25.3  7.1  5.5  14.1  20.4  112.0
# 2  ...  0.793   9.1  34.9  44.0  24.0  7.4  5.0  13.7  18.6  108.4
# 3  ...  0.732   9.5  34.5  44.0  24.0  7.6  5.2  14.5  20.2  112.1
# 4  ...  0.776  10.2  36.5  46.7  23.9  7.6  4.0  13.4  18.2  115.5
#
# [5 rows x 22 columns]

# %%
X.describe()
# Out:
#          Salary cap        Wins      Losses         PCT          FG  \
# count  1.480000e+02  148.000000  148.000000  148.000000  148.000000
# mean   1.241885e+08   39.054054   38.608108    0.501682   40.714189
# std    1.715505e+07   11.675769   11.160935    0.143210    1.608608
# min    7.918008e+07   15.000000   17.000000    0.207000   36.700000
# 25%    1.150038e+08   31.000000   30.000000    0.402000   39.400000
# 50%    1.238596e+08   41.500000   38.000000    0.524000   40.700000
# 75%    1.320837e+08   48.000000   46.000000    0.610250   41.900000
# max    1.789808e+08   65.000000   65.000000    0.793000   44.700000
#
#               FG%          3P         3P%          2P         2P%  ...  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000  ...
# mean     0.462068   11.833108    0.359000   28.883108    0.524311  ...
# std      0.013792    1.681245    0.015259    2.141599    0.020920  ...
# min      0.429000    8.000000    0.326000   23.100000    0.476000  ...
# 25%      0.451000   10.675000    0.349000   27.375000    0.509000  ...
# 50%      0.464000   11.600000    0.357000   29.000000    0.525000  ...
# 75%      0.471000   12.925000    0.369000   30.525000    0.540250  ...
# max      0.503000   16.700000    0.411000   33.400000    0.575000  ...
#
#               FT%         ORB         DRB         TRB         AST         STL  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000  148.000000
# mean     0.772446   10.091892   34.377027   44.462162   24.365541    7.650000
# std      0.028816    1.014354    1.636409    1.927545    1.928085    0.780851
# min      0.694000    8.000000   31.000000   39.800000   19.500000    6.100000
# 25%      0.753750    9.400000   33.400000   43.000000   23.175000    7.100000
# 50%      0.774500   10.000000   34.300000   44.350000   24.100000    7.600000
# 75%      0.792000   10.625000   35.400000   45.500000   25.725000    8.200000
# max      0.839000   14.100000   42.200000   51.700000   29.400000   10.000000
#
#               BLK         TOV          PF         PTS
# count  148.000000  148.000000  148.000000  148.000000
# mean     4.860811   14.114865   20.114865  110.510811
# std      0.697384    1.068368    1.396369    4.246105
# min      2.400000   11.100000   17.200000   98.800000
# 25%      4.400000   13.400000   19.100000  107.275000
# 50%      4.900000   14.100000   20.050000  111.200000
# 75%      5.300000   14.800000   21.125000  113.700000
# max      7.500000   17.000000   23.600000  120.100000
#
# [8 rows x 21 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# Yes    79
# No     69
# Name: Playoffs, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({'No': 51, 'Yes': 60})

# %% [markdown]
# # Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier

from imblearn.ensemble import BalancedRandomForestClassifier
rando_forest_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
rando_forest_model.fit(X_train, y_train)
print(Counter(y_train))
# Out:
# Counter({'Yes': 60, 'No': 51})

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

y_pred = rando_forest_model.predict(X_test)
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263157

# %%
# Display the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(cm, index=["Actual No_Playoffs", "Actual Yes_Playoffs"], columns=["Predicted No_Playoffs", "Predicted Yes_Playoffs"])
cm_df
# Out:
#                      Predicted No_Playoffs  Predicted Yes_Playoffs
# Actual No_Playoffs                      18                       0
# Actual Yes_Playoffs                      1                      18

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#          No       0.95      1.00      0.95      0.97      0.97      0.95        18
#         Yes       1.00      0.95      1.00      0.97      0.97      0.94        19
#
# avg / total       0.97      0.97      0.97      0.97      0.97      0.95        37

# %%
# # List the features sorted in descending order by feature importance
# features_sorted = sorted(zip(rando_forest_model.feature_importances_, X.columns), reverse=True)
# for importance in importances:
#     print(f'{importance[1]}:  {importance[0]*100:.1f}%')
    
    
features_rank = sorted(zip(rando_forest_model.feature_importances_, X.columns), reverse=True)
for feature in features_rank:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# PCT: (0.24235275544328821)
# Losses: (0.1982509642267184)
# Wins: (0.17379346284855346)
# 3P%: (0.050737682641564044)
# Salary cap: (0.040758574188756856)
# FT%: (0.03757087352460228)
# TOV: (0.03462708428600668)
# DRB: (0.03256322108991682)
# TRB: (0.02305405018045281)
# STL: (0.019222598823752646)
# FG%: (0.01858309764446913)
# FT: (0.017302746566066694)
# BLK: (0.016789715559538936)
# 2P%: (0.015466644512926526)
# PF: (0.014030867163444673)
# ORB: (0.01211611436207838)
# PTS: (0.011698258562187978)
# FG: (0.011518962638296095)
# 2P: (0.011512454521434292)
# 3P: (0.009790560991291546)
# AST: (0.008259310224653493)
